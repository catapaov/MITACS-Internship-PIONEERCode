# %% [markdown]
# This notebook is used to display the fits of the charge distribution in order to extract the number of photoelectrons from the SPE distribution.
#
# Note that the displayed distributions are not SPEs themselves, but are used just to quickly check how many photoelectrons we are seeing.
#
# The implementation of the functions is in the file SPE_fit.py. The general idea is to change the filename to the desired one and run the function: "compute_area(file, t0, t1)"
# Here, t0 is the time at which the PMT pulse starts, and t1 is the time point when the pulse ends. This function computes the area-charge of the pulse.
#
# After that, you must call the function: "plot_and_compute_spe()"
#
# This function performs the fit and displays the result.

# %%
import SPE_fit as spe

date= '25-07-24'
PMT_ID = 'BA0100'
v_set= 1100
LED_ID = "308"
t0, t1   = 0.38e-7, 2e-7

# %%
file= f"/home/aovelencio/PMTTesting/SPE_PMT_data/{date}/CHARGE_CHECK_1e4wf_SPEdataTest_{PMT_ID}-{v_set}V_L-{LED_ID}_LASER-ON_CH1.csv"

# %%
df=spe.compute_area(file,t0,t1)
areas = df['Area'].values

# %%
spe.plot_and_compute_spe(areas)
# Out:
# Results of Double Gaussian fit:
#
#  Pedestal mean (mu0): 1.88e-11 C
# Pedestal sigma (sigma0): 2.86e-12 C
# Pedestal amplitude (A0): 1.22e+02
# R² of fit: 9.85e-01

# %%
file= f"/home/aovelencio/PMTTesting/SPE_PMT_data/{date}/CHARGE_CHECK_1e4wf_SPEdataTest_{PMT_ID}-{v_set}V_L-{LED_ID}_LASER-ON_CH1.csv"

# %%
df=spe.compute_area(file,t0,t1)
areas = df['Area'].values

# %%
spe.plot_and_compute_spe(areas)
# Out:
# Results of Double Gaussian fit:
#
#  Pedestal mean (mu0): 1.88e-11 C
# Pedestal sigma (sigma0): 2.86e-12 C
# Pedestal amplitude (A0): 1.22e+02
# R² of fit: 9.85e-01

# %%
file= f"/home/aovelencio/PMTTesting/SPE_PMT_data/{date}/CHARGE_CHECK_1e3wf_SPEdataTest_{PMT_ID}-{v_set}V_L-{LED_ID}_LASER-ON_CH1.csv"

# %%
df=spe.compute_area(file,t0,t1)
areas = df['Area'].values

# %%
spe.plot_and_compute_spe(areas)
# Out:
# Results of Double Gaussian fit:
#
#  Pedestal mean (mu0): 1.82e-11 C
# Pedestal sigma (sigma0): 3.07e-12 C
# Pedestal amplitude (A0): 1.25e+02
# R² of fit: 9.70e-01

# %%
file= "/home/aovelencio/PMTTesting/SPE_PMT_data/25-07-16/SPEdataTest_BA0131-1300V_L-235_LASER-ON_CH1.csv"

# %%
df=spe.compute_area(file,t0,t1)
areas = df['Area'].values

# %%
spe.plot_and_compute_spe(areas)
# Out:
# Results of Double Gaussian fit:
#
#  Pedestal mean (mu0): 1.04e-09 C
# Pedestal sigma (sigma0): 2.12e-11 C
# Pedestal amplitude (A0): 1.06e+01
# R² of fit: 7.94e-01

# %%
#2.4e3 photoelectrons from fit
#1.1e5 electrons from photodiode calibration

# %%
file= "/home/aovelencio/PMTTesting/SPE_PMT_data/25-07-16/SPEdataTest_BA0131-1200V_L-235_LASER-ON_CH1.csv"

# %%
df=spe.compute_area(file,t0,t1)
areas = df['Area'].values

# %%
spe.plot_and_compute_spe(areas)
# Out:
# Results of Double Gaussian fit:
#
#  Pedestal mean (mu0): 6.07e-10 C
# Pedestal sigma (sigma0): 1.64e-11 C
# Pedestal amplitude (A0): 1.05e+01
# R² of fit: 7.01e-01

# %%
#1.36 photoelectrons from fit
